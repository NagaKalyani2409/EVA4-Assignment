# %% [markdown]
# <a href="https://colab.research.google.com/github/NagaKalyani2409/EVA4-Assignment/blob/master/S15A_DenseDepth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My\ Drive/S15A
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/S15A

# %%
# !ls -l
# Out:
# total 3502735
# drwx------ 2 root root       4096 May  8 13:25  Background
# drwx------ 2 root root       4096 May 10 17:17  DenseDepth
# -rw------- 1 root root       4543 May 11 12:54  Depth1.ipynb
# drwx------ 2 root root       4096 May 10 06:07  fg_bg
# -rw------- 1 root root 3585528886 May 10 04:08  fg_bg1.zip
# drwx------ 2 root root       4096 May  8 13:28  masked
# drwx------ 2 root root       4096 May  8 13:27  People
# -rw------- 1 root root      55789 May 11 14:10 'S15A (1).ipynb'
# -rw------- 1 root root     818541 May 11 14:25 'S15A DenseDepth.ipynb'
# -rw------- 1 root root     371164 May  9 11:46  t_labels.txt

# %%
# !ls -l fg_bg
# Out:
# total 12
# drwx------ 2 root root 4096 May 10 06:07 fg_bg
# drwx------ 2 root root 4096 May 10 06:07 fg_bg_mask
# drwx------ 2 root root 4096 May 10 06:08 labels

# %%
# %cd /content/gdrive/My\ Drive/S15A/DenseDepth
# Out:
# /content/gdrive/My Drive/S15A/DenseDepth

# %%
# !ls -l
# Out:
# total 347771
# -rw------- 1 root root      9471 May 10 17:17 augment.py
# -rw------- 1 root root      3946 May 10 17:17 callbacks.py
# -rw------- 1 root root      7916 May 10 17:17 data.py
# -rw------- 1 root root   2457728 May 10 17:17 demo_depth.npy
# -rw------- 1 root root     14392 May 10 17:17 demo.py
# -rw------- 1 root root   7372928 May 10 17:17 demo_rgb.npy
# -rw------- 1 root root      1581 May 10 17:17 evaluate.py
# drwx------ 2 root root      4096 May 10 17:17 examples
# -rw------- 1 root root 172897384 May 11 13:14 kitti.h5
# -rw------- 1 root root      2112 May 10 17:17 layers.py
# -rw------- 1 root root     35149 May 10 17:17 LICENSE
# -rw------- 1 root root       673 May 10 17:17 loss.py
# -rw------- 1 root root      3087 May 10 17:17 model.py
# -rw------- 1 root root 172897376 May 10 17:18 nyu.h5
# drwx------ 2 root root      4096 May 10 17:17 __pycache__
# drwx------ 2 root root      4096 May 10 17:17 PyTorch
# ...

# %%
# !python test.py
# Out:
# Using TensorFlow backend.
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (15) images of size (224, 224, 3).
# It took:  53.45714569091797

# %%
from skimage import io
import cv2
import matplotlib.pyplot as plt
plt.clf()
plt.figure(figsize=(18,18))
plt.imshow( io.imread('/content/gdrive/My Drive/S15A/DenseDepth/results.jpg'),cmap='inferno' )

# %%
plt.figure(figsize=(5,5))
plt.imshow( io.imread('/content/gdrive/My Drive/S15A/Background/bg_001.png'),cmap='inferno' )

# %%
plt.figure(figsize=(5,5))
plt.imshow( io.imread('/content/gdrive/My Drive/S15A/People/fg_001.png'),cmap='inferno' )

# %%
plt.figure(figsize=(5,5))
plt.imshow( io.imread('/content/gdrive/My Drive/S15A/fg_bg/fg_bg/bg_000/fg_000_bg_000_000001.jpg'),cmap='inferno' )

# %%
plt.figure(figsize=(5,5))
plt.imshow( io.imread('/content/gdrive/My Drive/S15A/fg_bg/fg_bg_mask/bg_000/fg_000_bg_000_mask_000001.jpg'),cmap='inferno' )
